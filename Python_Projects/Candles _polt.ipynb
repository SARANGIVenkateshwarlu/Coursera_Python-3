# %% [markdown]
# **PLRT history stock data (CSV) Candles Plot**

# %%
import pandas as pd
import mplfinance as mpf

# %%
data = pd.read_csv("D:/DropBox Files/Dropbox/Python coding-1/Python Basics/Download Data - STOCK_US_XNAS_PLTR.csv")

# %%
data
# Out:
#           Date    Open    High     Low   Close       Volume
# 0    8/27/2025  162.32  162.40  155.98  156.72   76380555.0
# 1    8/26/2025  155.39  162.13  154.57  160.87   86573719.0
# 2    8/25/2025  156.10  158.59  149.37  157.17   86879820.0
# 3    8/22/2025  155.32  163.20  151.77  158.74  102099203.0
# 4    8/21/2025  157.17  157.97  153.81  156.18   94678641.0
# ..         ...     ...     ...     ...     ...          ...
# 142   2/3/2025   80.13   84.25   78.47   83.74  126592703.0
# 143  1/31/2025   81.00   85.22   80.87   82.49   79000227.0
# 144  1/30/2025   80.02   81.83   79.38   81.22   46067527.0
# 145  1/29/2025   79.95   80.82   77.81   79.76   49262160.0
# 146  1/28/2025   75.54   80.74   74.04   80.23   65916656.0
#
# [147 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    147 non-null    object
#  1   Open    147 non-null    float64
#  2   High    147 non-null    float64
#  3   Low     147 non-null    float64
#  4   Close   147 non-null    float64
#  5   Volume  147 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 7.0+ KB

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
data.Date = pd.to_datetime(data.Date)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    147 non-null    datetime64[ns]
#  1   Open    147 non-null    float64
#  2   High    147 non-null    float64
#  3   Low     147 non-null    float64
#  4   Close   147 non-null    float64
#  5   Volume  147 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 7.0 KB

# %%
data
# Out:
#           Date    Open    High     Low   Close       Volume
# 0   2025-08-27  162.32  162.40  155.98  156.72   76380555.0
# 1   2025-08-26  155.39  162.13  154.57  160.87   86573719.0
# 2   2025-08-25  156.10  158.59  149.37  157.17   86879820.0
# 3   2025-08-22  155.32  163.20  151.77  158.74  102099203.0
# 4   2025-08-21  157.17  157.97  153.81  156.18   94678641.0
# ..         ...     ...     ...     ...     ...          ...
# 142 2025-02-03   80.13   84.25   78.47   83.74  126592703.0
# 143 2025-01-31   81.00   85.22   80.87   82.49   79000227.0
# 144 2025-01-30   80.02   81.83   79.38   81.22   46067527.0
# 145 2025-01-29   79.95   80.82   77.81   79.76   49262160.0
# 146 2025-01-28   75.54   80.74   74.04   80.23   65916656.0
#
# [147 rows x 6 columns]

# %%
data =data.set_index("Date")

# %%
mpf.plot(data)

# %%
# Sort the DataFrame by 'Date' in ascending order
data.sort_values(by='Date', ascending=True, inplace=True)

# %%
mpf.plot(data)

# %%
mpf.plot(data, type= 'candle')

# %%
mpf.plot(data, type= 'candle', mav=(21), figratio = (20, 12), style = 'yahoo', volume = True, title ='PLTR' )
